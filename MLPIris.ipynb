# %% [markdown]
# <a href="https://colab.research.google.com/github/Ar7huur/C/blob/master/MLPIris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import np_utils # para aplicar one hot encoding

# %%
#importar base iris
#primeiro temos
from sklearn.datasets import load_iris
base = load_iris()
atributos = base.data
classes=base.target #ou base.target_names

#segundo temos:
#base = pd.read_csv("urus.csv")
#atributos base.iloc [:, 0:4].values para pegar as colunas, de 0 a 4 são 5 colunas e o values converte prara array (: indica todas as linhas)
#classes = base.iloc[:,4]

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
classes = labelencoder.fit_transform(classes_nomes) #em classes pode ser a classe string
classes_dummy = np_utils.to_categorical(classes)

# %%
from sklearn.model_selection import train_test_split
treino,teste,classe_treino,classe_teste = train_test_split (atributos,classes_dummy,test_size = 0.25)

# %%
mlp = Sequential()
mlp.add(Dense(units=4, activation="relu", kernel_initializer="random_uniform", input_dim=4))
mlp.add(Dense(units=4, activation="relu", kernel_initializer="random_uniform"))
mlp.add(Dense(units=3, activation="softmax")) #em saida eh 3
mlp.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["categorical_accuracy"])#adam eh o gradiente decendente otimizado

# %%
mlp.summary() #exibe tudo que foi gerado
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 4)                 20
#
#  dense_4 (Dense)             (None, 4)                 20
#
#  dense_5 (Dense)             (None, 3)                 15
#
# ...
# Total params: 55
# Trainable params: 55
# Non-trainable params: 0
# _________________________________________________________________

# %%
mlp.fit(treino,classe_treino,batch_size=10, epochs=1000)
# Out:
# Epoch 1/1000
# 12/12 [==============================] - 1s 3ms/step - loss: 1.0980 - categorical_accuracy: 0.3304
# Epoch 2/1000
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0960 - categorical_accuracy: 0.3304
# Epoch 3/1000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0938 - categorical_accuracy: 0.3304
# Epoch 4/1000
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0910 - categorical_accuracy: 0.3304
# Epoch 5/1000
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0875 - categorical_accuracy: 0.3304
# Epoch 6/1000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0820 - categorical_accuracy: 0.3304
# Epoch 7/1000
# 12/12 [==============================] - 0s 3ms/step - loss: 1.0768 - categorical_accuracy: 0.3304
# Epoch 8/1000
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0732 - categorical_accuracy: 0.3304
# Epoch 9/1000
# ...

# %%
resultado = mlp.evaluate(teste,classe_teste)
# Out:
# 2/2 [==============================] - 0s 8ms/step - loss: 0.0433 - categorical_accuracy: 0.9737
